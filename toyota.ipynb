# %% [markdown]
# <a href="https://colab.research.google.com/github/priyatham-18/Homework/blob/main/toyota.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: upload and read xslx file

# Install the required library if it's not already installed
# !pip install pandas openpyxl

import pandas as pd
from google.colab import files
import io

# Upload the file
uploaded = files.upload()

# Check if a file was uploaded
if len(uploaded) > 0:
  # Get the filename
  filename = next(iter(uploaded))

  # Read the Excel file into a pandas DataFrame
  try:
    df = pd.read_excel(io.BytesIO(uploaded[filename]), engine='openpyxl')
    print("File successfully read.")
    # Display the first 5 rows of the DataFrame
    print(df.head())
  except Exception as e:
    print(f"An error occurred: {e}")
else:
  print("No file was uploaded.")
# Out:
# ...
#      <input type="file" id="files-454c5290-e570-495f-ac52-04803c426dd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-454c5290-e570-495f-ac52-04803c426dd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
file_name=list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-02a7fd5e-07e8-4acf-8ebc-ec811f707421" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02a7fd5e-07e8-4acf-8ebc-ec811f707421">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
toyoto.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d9173d87c250> in <cell line: 0>()
# ----> 1 toyoto.shape
#
# NameError: name 'toyoto' is not defined
